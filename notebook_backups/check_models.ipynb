# %%
from nlp_models import get_general_model

device_map="cpu"
lm_cache_dir = '/data1/bumjin/datahub'
for lm_name in ['llama3', 'llama3_1', 'llama3_1_instruct', 'llama3_3_instruct']:
    for lm_size in ['8b', ]:  # '70b'
        print(lm_name, lm_size)
        get_general_model(lm_name, lm_size, lm_cache_dir, device_map='auto', precision=None, return_tokenizer_only=False)
# Out:
# llama3 8b
# 2025-02-14 14:23:49.541265: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-14 14:23:49.559908: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-14 14:23:49.578978: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-14 14:23:49.584473: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
