# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


model_name_mapping = {
    
}

base_dir = "results"
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(root, file))
# Out:
# ['experiment2_1', 'experiment3', 'experiment2_2', 'experiment 6', 'experiment1', 'experiment5']

# %%
# Experiment 1
models = ['gpt4o', 'gpt4o_mini', 'llama3_1_instruct_70b', 
          'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b']

answer_types = ['Binary', 'Ternary', 'Regression']
setting_models = {
    'Binary': ['gpt4o', 'gpt4o_mini', 'llama3_1_instruct_70b', 'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b'],
    'Ternary': ['gpt4o', 'gpt4o_mini',  'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b'],
    'Regression': ['gpt4o', 'gpt4o_mini',  'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b']
}

for answer_type in answer_types:
    for model in setting_models[answer_type]:
        path = f"results/experiment1/{answer_type}/{model}.csv"
        if not os.path.exists(path):
            print("File does not exist: ", path)
print("Check done")
# Out:
# Check done

# %%
# Experiment 2_1

answer_types = ['Binary', 'Ternary', 'Regression']
setting_models = {
    'Binary': ['gpt4o', 'gpt4o_mini', 'llama3_1_instruct_70b', 'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b'],
    'Ternary': ['gpt4o', 'gpt4o_mini',  'llama3_8b', 'gemma2_9b', 'exaone_8b', ],
    'Regression': ['gpt4o', 'gpt4o_mini', 'llama3_8b', 'gemma2_9b', 'exaone_8b', ]
}
datasets = ['dataset2', 'dataset3', 'dataset4']
for dataset in datasets:
    for answer_type in answer_types:
        for model in setting_models[answer_type]:
            path = f"results/experiment2_1/{answer_type}/{dataset}/{model}.csv"
            if not os.path.exists(path):
                print("File does not exist: ", path)
print("Check done")
# Out:
# Check done

# %%
# Experiment 2_2
question_types = ['general', 'explicit', 'strict']
setting_models = {
    'general': ['gpt4o', 'gpt4o_mini',  'llama3_8b', 'gemma2_9b', 'exaone_8b',],
    'explicit': ['gpt4o', 'gpt4o_mini',  'llama3_8b', 'gemma2_9b', 'exaone_8b', ],
    'strict': ['gpt4o', 'gpt4o_mini', 'llama3_8b', 'gemma2_9b', 'exaone_8b', ]
}

datasets = ['dataset1', 'dataset2']
for dataset in datasets:
    for question_type in question_types:
        for model in setting_models[question_type]:
            path = f"results/experiment2_2/Binary/{dataset}/{question_type}/{model}.csv"
            if not os.path.exists(path):
                print("File does not exist: ", path)
print("Check done")
# Out:
# Check done

# %%
# Experiment 3
question_types = ['base', 'deontic']
setting_models = {
    'base': ['gpt4o', 'gpt4o_mini', 'llama3_1_instruct_70b', 'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b'],
    'deontic': ['gpt4o', 'gpt4o_mini', 'llama3_1_instruct_70b', 'llama3_8b', 'gemma2_9b', 'exaone_8b', 'qwen2_7b'],
}

datasets = ['dataset5', ]
for dataset in datasets:
    for question_type in question_types:
        for model in setting_models[question_type]:
            path = f"results/experiment3/dataset5/{question_type}/Regression/{model}.csv"
            if not os.path.exists(path):
                print("File does not exist: ", path)
print("Check done")
# Out:
# Check done
