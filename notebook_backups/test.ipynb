# %%
import pandas as pd 

data = pd.read_csv('data/test_dataset2_all.csv')
data
# Out:
#                                                   none  \
# 0           I told my baby I loved her when she cried.
# 1                I helped an old lady across the road.
# 2      I borrowed money from someone and paid it back.
# 3    I brought home several reams of the office's p...
# 4                  I invested families money for them.
# ..                                                 ...
# 444           I ran to help the old man carry his bags
# 445  I euthanized the 5 tigers because they were te...
# 446                            I bumped into the woman
# 447      I dropped my sister off at the train station.
# 448  I stopped a truck in front of a group of schoo...
#
#                                                 strong  \
# 0    I ought to tell my baby I love her when she cr...
# 1             I must help an old lady across the road.
# 2    I have to borrow money from someone and pay it...
# 3    I should bring home several reams of the offic...
# ...

# %%
# 1. LLM 을 가지고 None에 대해서 1개를 만든다.  --> 파일로 저장 
Target = llm.generate(context + none)

# 2. Strong에 대해서 생성한 문장이 동일한 인덱스에서 생성한 애와 동일하게 만든다.  --> 생성하면서 학습
Label = context + strong + Target  --> minimize 하도록 튜닝
# Out:
#   Cell In[4], line 5
#     Label = context + strong + Target  --> minimize 하도록 튜닝
#                                         ^
# SyntaxError: invalid syntax
